# %%
### importing things we need
import numpy as np
import dask
import dask.array as da
from glob import glob
from h5py import File
import matplotlib.pyplot as plt
import imageio
from PIL import Image

# %%
imDir = r'Z:\Alex\ketamine_paper\grabne\20230802_grabne_ket\f2_ket_20230802_151647\mov'
imFiles = glob(imDir + '\\*.tif')
print(imFiles)
# Out:
# ['Z:\\Alex\\ketamine_paper\\grabne\\20230802_grabne_ket\\f2_ket_20230802_151647\\mov\\0.tif', 'Z:\\Alex\\ketamine_paper\\grabne\\20230802_grabne_ket\\f2_ket_20230802_151647\\mov\\10.tif', 'Z:\\Alex\\ketamine_paper\\grabne\\20230802_grabne_ket\\f2_ket_20230802_151647\\mov\\20.tif', 'Z:\\Alex\\ketamine_paper\\grabne\\20230802_grabne_ket\\f2_ket_20230802_151647\\mov\\30.tif', 'Z:\\Alex\\ketamine_paper\\grabne\\20230802_grabne_ket\\f2_ket_20230802_151647\\mov\\40.tif', 'Z:\\Alex\\ketamine_paper\\grabne\\20230802_grabne_ket\\f2_ket_20230802_151647\\mov\\50.tif']

# %%
plt.figure(figsize=(21,13))
for i in range(len(imFiles)):
    image = imageio.imread(imFiles[i])
    plt.subplot(2,3,i+1)
    plt.imshow(image.T,vmin = -0.05,vmax=0.05,cmap = 'coolwarm')
plt.colorbar()
plt.savefig(r'Z:\Alex\ketamine_paper\grabne\20230802_grabne_ket\f2_ket_20230802_151647\mov\summarymap.png',dpi=300)

# %%
plt.figure()
plt.imshow(image,vmin = -0.2,vmax=0.2,cmap = 'coolwarm')
plt.colorbar()
